# %% [markdown]
# 1)what is data structures,and why they important?
# In Python, data structures are built-in or user-defined ways to organize and manage data effectively for efficient access and modification. Python provides several native data structures as part of its standard library, making it easy for developers to store, manipulate, and access data efficiently.
#
# Why are Data Structures Important in Python?
# Efficient Data Storage and Retrieval:
# Data structures help in managing large volumes of data with minimal overhead.
#
# Performance Optimization:
# Selecting the right data structure can greatly improve execution speed.
#
# Real-world Applications:
#
# Lists: Used in data aggregation and dynamic storage.
# Dictionaries: Efficient for database indexing and key-value lookups.
# Sets: Used in membership testing and eliminating duplicates.
# Memory Efficiency:
# Python's dynamic memory allocation and garbage collection benefit from well-structured data storage.
#
# Algorithm Support:
# Many algorithms rely on specific data structures for tasks like searching, sorting, and graph processing.
#
# 2)Explain the difference between mutable and immutable data types with examples?
# ans:Mutable Data Types
# These data types allow modification after their creation. Changes happen in-place without creating a new object.
# examples:1)list 2)Dictionary 3)set
# Immutable Data Types
# These data types cannot be modified after their creation. Any attempt to change them creates a new object.
# Examples:1)Srting 2)Tuple 3)Integer
#
# 3)what are the main differences between lists and tuples in python?
# ans:
#
# A list in Python is an ordered, mutable collection of elements that can hold items of different data types, such as integers, strings, floats, or even other lists. Lists are defined using square brackets [ ], and their elements are separated by commas.
# Ordered: Elements have a defined sequence and can be accessed by index.
# Mutable: Elements can be added, removed, or modified.
# Heterogeneous: Can store different data types in a single list.
# Dynamic: Size can change as elements are added or removed.
#
# A tuple in Python is an ordered, immutable collection of elements. Unlike lists, tuples cannot be modified after creation, making them useful for storing fixed data. Tuples are defined using parentheses ( ), and their elements are separated by commas.
# Key Characteristics of Tuples
# Ordered: Elements have a defined sequence and can be accessed by index.
# Immutable: Elements cannot be added, removed, or changed after the tuple is created.
# Heterogeneous: Can store different data types (e.g., integers, strings, floats).
# Hashable: Can be used as keys in dictionaries (if all elements are immutable).
#
# 4)Describe how dictionaries store data.
#
# In Python, dictionaries store data as key-value pairs using a highly efficient data structure called a hash table. A dictionary is defined by curly braces {} and stores mappings of unique, immutable keys to values, which can be of any data type.
# Internal Working:
# Hashing Keys:
#
# When a key-value pair is added to a dictionary, the key is passed through a hashing function that generates a unique integer called a hash value.
# This hash value determines the storage location (or "bucket") for the key-value pair in memory.
# Storing Values:
#
# The computed hash value maps to a specific slot in the dictionary’s hash table, where the corresponding value is stored.
# Collision Handling:
#
# Hash collisions occur when two keys produce the same hash value.
# Python uses techniques such as open addressing or chaining to resolve collisions and ensure efficient data storage.
#
# 5)why might you use a set instead of a list in python?
#  ans:A set in Python is an unordered collection of unique elements, defined using curly braces {} or the set() constructor. Although lists are more flexible, sets offer distinct advantages in specific scenarios.
#
# 6)What is a String in python ,and how is it different from a list?
# ans: A string in Python is a sequence of characters enclosed within single quotes ' ', double quotes " ", or triple quotes ''' '''/""" """. Strings are immutable, meaning they cannot be changed after creation.
# Key Functional Differences
# Data Storage:
#
# Strings store only characters, while lists can store any data type (integers, strings, floats, etc.).
# Mutability:
#
# Strings are immutable, requiring a new string for changes. Lists are mutable, allowing in-place modifications.
# Methods:
#
# Strings have methods for text operations like replace(), lower(), upper().
# Lists have methods like append(), insert(), and pop() for list operations.
#
# 7)How do tuples ensure data integrity in python?
#
# Tuples in Python are immutable, which means once they are created, their contents cannot be modified (no element can be added, removed, or changed). This immutability plays a crucial role in ensuring data integrity by protecting data from accidental or intentional modification.
#
# Ways Tuples Ensure Data Integrity
# Immutability Protects Data Consistency:
#
# Since tuples cannot be changed, they help maintain a consistent state for data throughout the program's execution.
# Prevents Unintended Changes:
#
# By design, any attempt to modify a tuple results in a TypeError, ensuring data is safeguarded against accidental modification.
# Reliable as Dictionary Keys:
#
# Tuples, being hashable, can be used as keys in dictionaries, unlike mutable types like lists. This makes them suitable for mapping complex keys to values.
#
# 8) What is a hash table,and how does it relate to dictionaries in Python?
# A hash table is a data structure that stores key-value pairs. It uses a hash function to compute a unique index (called a hash value) for each key, which determines where the corresponding value is stored in memory.
# Relationship Between Hash Tables and Dictionaries in Python
# Python dictionaries (dict) are built on top of hash tables.
# The keys in a dictionary are passed through a hash function, and their corresponding values are stored at specific memory locations.
#
# 9) can lists contain different data types in python?
# ans:Yes, lists can contain different data types in Python. A single list can store integers, floats, strings, booleans, objects, and even other lists simultaneously. This makes Python lists highly flexible and versatile.
#
# 10)Explain why strings are immutable in python?
# Strings in Python are immutable, meaning once a string is created, it cannot be changed or modified. This immutability has several design, performance, and security benefits.
# Reasons for String Immutability
# Memory Efficiency (String Interning)
#
# Python uses a technique called string interning, where identical strings share the same memory location to reduce memory usage.
# If strings were mutable, changing one would affect all references to the same string.
#
# 11)What advantages do dictionaries offer over lists for certain tasks?
# Dictionaries and lists are both versatile data structures in Python. However, dictionaries offer distinct advantages for specific use cases due to their key-value pair structure and efficient data retrieval.
#
#  12)Describe a scenario where using a tuple would be preferable over a list?
# Scenario: Storing GPS coordinates (latitude and longitude)
#
# In applications like mapping software, GPS tracking systems, or geospatial analysis, a tuple is preferable for storing coordinates because the data should remain constant. For instance, the latitude and longitude of a location do not change. Using a tuple enforces immutability, ensuring that the coordinates remain intact.
#
# 13)How do sets handle duplicate values in python?
#
# In Python, sets automatically eliminate duplicate values. When you create a set or add elements to it, any duplicate values are ignored, and only unique elements are retained.
# How It Works
# When you create a set, Python checks each element and stores only unique values.
# If you try to add an element that already exists in the set, it is ignored.
#
# 14)How does the "in" keyword work differently for lists and dictionaries?
# The in keyword is used to check for membership in both lists and dictionaries, but it behaves differently for each.
#
# in with Lists
# When used with a list, the in keyword checks whether a specific value exists in the list.
#
# 15)can you modify the elements of a tuple ? expain why or why not.
# No, you cannot modify the elements of a tuple directly in Python because tuples are immutable. Once a tuple is created, its elements cannot be changed, added, or removed.
#
# 16)what is nested dictionary,and give an example of its use case?
#
#  ans:A nested dictionary is a dictionary inside another dictionary. This allows hierarchical or structured data storage, where each key can map to another dictionary as its value.
#  Use Case of Nested Dictionary: Storing Student Records
# Imagine you need to store student information, including names, subjects, and scores.
#
# 17)Describe the time complexity of accessing elementary in a dictionary?
#
# ans:The time complexity of accessing an element in a dictionary in Python is:
#
# Average Case: O(1) (constant time)
# Worst Case: O(n) (linear time)
#
# 18) In what situations are lists prefered over dictionaries?
# While dictionaries offer fast key-based access and structured data storage, lists remain preferable in many scenarios due to their sequential nature and other advantages.
#
#  19)why are dictionaries considered unordered ,and how does that affect data retrieval?
#  Ans:In earlier versions of Python (prior to Python 3.7), dictionaries were considered unordered collections. This meant that the order of elements in a dictionary was not guaranteed to be the same as the order in which they were inserted.
#
# However, starting from Python 3.7, dictionaries maintain insertion order as part of their standard behavior, making them more predictable.
#
# 20)Explain the difference between a list and a dictionaries in terms of data retrieval?
#  Data Retrieval by Index (List)
# Lists allow retrieval by numeric index starting from 0.
# Searching for specific values in unsorted lists requires scanning all elements.
#  Data Retrieval by Key (Dictionary)
# Dictionaries retrieve values using keys instead of indices.
# Keys can be strings, integers, or any immutable type.
#
# #Practical Quetions
#
# 1)# write a code to create  a string with your name and print it.
# # Creating a string with your name
# name = "Krushna Nirde"  # Replace with your name
# print("My name is:", name)

# %%
1)# write a code to create  a string with your name and print it.
# Creating a string with your name
name = "Krushna Nirde"  # Replace with your name
print("My name is:", name)

2)#write a code to find the lenght of the string "Hello World".
# Define the string
text = "Hello World"

# Find and print the length of the string
length = len(text)
print("The length of the string is:", length)

3)# write a code to slice the first 3 characters from the string "python programming".
# Define the string
text = "python programming"

# Slice the first 3 characters
slice_result = text[:3]

# Print the result
print("The first 3 characters are:", slice_result)

4)# Write a code to convert the string "hello" to uppercase.
# Define the string
text = "hello"

# Convert the string to uppercase
uppercase_text = text.upper()

# Print the result
print("Uppercase version:", uppercase_text)

5)# write a code to replace the word "apple" with "orange" in the string "i like apple".
# Define the string
text = "I like apple"

# Replace "apple" with "orange"
updated_text = text.replace("apple", "orange")

# Print the result
print("Updated string:", updated_text)

6) # write a code to create  a list with numbers 1 to 5 and print it.

# Create a list with numbers 1 to 5
numbers = [1, 2, 3, 4, 5]

# Print the list
print("The list is:", numbers)

7) # write a code to append the numbers 10 to the list [1,2,3,4].
# Define the list
numbers = [1, 2, 3, 4]

# Append the number 10 to the list
numbers.append(10)

# Print the updated list
print("Updated list:", numbers)

8)# write a code to remove the numbers 3 from the list[1,2,3,4,5].
# Define the list
numbers = [1, 2, 3, 4, 5]

# Remove the number 3 from the list
numbers.remove(3)

# Print the updated list
print("Updated list:", numbers)

9)# write a code to access the second elements in the list ['a','b','c','d']
# Define the list
letters = ['a', 'b', 'c', 'd']

# Access the second element
second_element = letters[1]

# Print the second element
print("Second element:", second_element)

10)# write a code to reserve the list [10,20,30,40,50]
# Define the list
numbers = [10, 20, 30, 40, 50]

# Reverse the list
numbers.reverse()

# Print the reversed list
print("Reversed list:", numbers)
11)#write a code to create a tuple with the elements 100,200,300 and print it.
# Create a tuple
numbers_tuple = (100, 200, 300)

# Print the tuple
print("Tuple:", numbers_tuple)

12)# write a code to access the second to last elements of the tuples('red','green','blue','yellow')
# Define the tuple
colors = ('red', 'green', 'blue', 'yellow')

# Access the second-to-last element
second_to_last = colors[-2]

# Print the result
print("Second-to-last element:", second_to_last)

13)# write a code to find the minimum number in the tuple(10,20,5,15)
# Define the tuple
numbers = (10, 20, 5, 15)

# Find the minimum number
min_number = min(numbers)

# Print the result
print("Minimum number:", min_number)

14)#write a code to find the index of the element 'cat' in the tuple('dog','cat','rabbit')

# Define the tuple
animals = ('dog', 'cat', 'rabbit')

# Find the index of 'cat'
cat_index = animals.index('cat')

# Print the result
print("Index of 'cat':", cat_index)

15)#write a code to create a tuple containing three different fruits and check if "kiwi"is in it
# Define the tuple
fruits = ('apple', 'banana', 'orange')

# Check if "kiwi" is in the tuple
if 'kiwi' in fruits:
    print("Yes, 'kiwi' is in the fruits tuple.")
else:
    print("No, 'kiwi' is not in the fruits tuple.")



16)#write a  code to create a set with the elements 'a','b','c' and print it.

# Create a set
my_set = {'a', 'b', 'c'}

# Print the set
print("Set:", my_set)

17)# write a code to clear all elements from the set {1,2,3,4,5}

# Create the set
my_set = {1, 2, 3, 4, 5}

# Clear all elements
my_set.clear()

# Print the cleared set
print("Cleared set:", my_set)


18) # write a  code to remove  the elements 4 from the set {1,2,3,4}


# Create the set
my_set = {1, 2, 3, 4}

# Remove the element 4
my_set.remove(4)

# Print the updated set
print("Updated set:", my_set)

19)# write a code to find  the union of the two sent{1,2,3}and {2,3,4}
# Define the sets
set1 = {1, 2, 3}
set2 = {2, 3, 4}

# Find the union of the sets
union_set = set1.union(set2)

# Print the result
print("Union of the sets:", union_set)

20)# write a code to find the intersection of two sets{1,2,3} and {2,3,4}
# Define the sets
set1 = {1, 2, 3}
set2 = {2, 3, 4}

# Find the intersection of the sets
intersection_set = set1.intersection(set2)

# Print the result
print("Intersection of the sets:", intersection_set)

21)# write a code to create a dictionary with the keys "name","age",and "city" and print it.

# Create the dictionary
person = {
    "name": "Alice",
    "age": 25,
    "city": "New York"
}

# Print the dictionary
print("Dictionary:", person)

22)#write a  code to add a new key value pair "country" :"USA" to Dictionary ('names':'alice','age':25)


# Define the dictionary
person = {'name': 'alice', 'age': 25}

# Add the new key-value pair
person['country'] = 'USA'

# Print the updated dictionary
print("Updated dictionary:", person)
Output:
pgsql
Copy
Edit
Updated dictionary: {'name': 'alice', 'age': 30, 'country': 'USA'}

23)# write a code to access the values associated with the key 'name' in the dictionary{'names':'Alias','age':30}


# Define the dictionary
person = {'names': 'Alias', 'age': 30}

# Access the value associated with the key 'names'
name_value = person['names']

# Print the value
print("Value associated with the key 'names':", name_value)



24)#write a code to remove the key "age" from the dictionary {'name':'bob','age':22,'city':'New York'}
# Define the dictionary
person = {'name': 'bob', 'age': 22, 'city': 'New York'}

# Remove the key "age"
person.pop('age')

# Print the updated dictionary
print("Updated dictionary:", person)

25)# write a code to check a list ,a tuple,and  a dictionary  and print them all.

# Define a list, a tuple, and a dictionary
my_list = [1, 2, 3, 4, 5]
my_tuple = ('apple', 'banana', 'cherry')
my_dict = {'name': 'Alice', 'age': 25, 'city': 'New York'}

# Check and print each data type
if isinstance(my_list, list):
    print("List:", my_list)

if isinstance(my_tuple, tuple):
    print("Tuple:", my_tuple)

if isinstance(my_dict, dict):
    print("Dictionary:", my_dict)


26)# write a code to check if the key "city" exits in the dictionary {'name':'Alice','city':'paris'}
# Define the dictionary
my_dict = {'name': 'Alice', 'city': 'paris'}

# Check if the key "city" exists
if "city" in my_dict:
    print("The key 'city' exists in the dictionary.")
else:
    print("The key 'city' does not exist in the dictionary.")


27) #write a code to create a list of 5 random numbers between 1 and 100 and sort it in ascending order and print the result
.
import random

# Generate a list of 5 random numbers between 1 and 100
random_numbers = random.sample(range(1, 101), 5)

# Sort the list in ascending order
random_numbers.sort()

# Print the result
print("Sorted list of random numbers:", random_numbers)


28)# write a code to create a list with strings and print the elements at the third index.

# Define a list with strings
string_list = ["apple", "banana", "cherry", "date", "elderberry"]

# Print the element at the third index (0-based indexing)
print("Element at third index:", string_list[3])


29)# write a code to combine two dictionaries into one and print the results.


# Define two dictionaries
dict1 = {'name': 'Alice', 'age': 25}
dict2 = {'city': 'Paris', 'country': 'France'}

# Combine the dictionaries using dictionary unpacking
combined_dict = {**dict1, **dict2}

# Print the result
print("Combined Dictionary:", combined_dict)



30)# write a code to convert a list of strings into a set.

# Define a list of strings
string_list = ["apple", "banana", "cherry", "apple", "banana"]

# Convert the list to a set
string_set = set(string_list)

# Print the result
print("Set of strings:", string_set)


































:
